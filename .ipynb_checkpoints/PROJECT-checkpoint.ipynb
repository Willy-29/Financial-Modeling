# %%
import pandas as pd #Importing libraries
import numpy as np
import math
import statistics
import matplotlib.pyplot as plt
import sklearn
from tqdm import tqdm

# %%
fontsize = 10 #setting plot paremeters
width_in_cm = 14.
params = {'figure.figsize': (width_in_cm , width_in_cm  * 9./16.),
          'axes.labelsize': fontsize*1.5,
          'axes.titlesize': fontsize*2,
          'xtick.labelsize': fontsize,
          'ytick.labelsize': fontsize,
          'legend.fontsize': fontsize*1}
plt.rcParams.update(params)

# %%
dataSPXS=pd.read_csv('SPXS.csv',index_col='Date', parse_dates=True)#Loading data
dataSPXS
dataSPXL=pd.read_csv('SPXL.csv',index_col='Date', parse_dates=True)
dataSPXL
dataSPY=pd.read_csv('SPY.csv', index_col='Date', parse_dates=True)
dataSPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  225.039993  225.830002  223.880005  225.240005  202.085281
# 2017-01-04  225.619995  226.750000  225.610001  226.580002  203.287521
# 2017-01-05  226.270004  226.580002  225.479996  226.399994  203.126007
# 2017-01-06  226.529999  227.750000  225.899994  227.210007  203.852768
# 2017-01-09  226.910004  227.070007  226.419998  226.460007  203.179840
# ...                ...         ...         ...         ...         ...
# 2023-03-27  398.119995  398.920013  395.559998  396.489990  396.489990
# 2023-03-28  395.769989  396.489990  393.690002  395.600006  395.600006
# 2023-03-29  399.929993  401.600006  398.679993  401.350006  401.350006
# 2023-03-30  404.089996  404.350006  401.760010  403.700012  403.700012
# 2023-03-31  404.660004  409.700012  404.549988  409.390015  409.390015
#
#                Volume
# Date
# 2017-01-03   91366500
# 2017-01-04   78744400
# 2017-01-05   78379000
# ...

# %%
print(dataSPXS.isna().values.any())#checking that there is no NaNs isnull().values.any()
print(dataSPXL.isnull().values.any())
print(dataSPY.isnull().values.any())
# Out:
# False
# False
# False

# %%
dataSPXS_close=dataSPXS.iloc[:,[3]]#Focussing on the close price
dataSPXL_close=dataSPXL.iloc[:,[3]]
dataSPY_close=dataSPY.iloc[:,[3]]
dataSPXS_close
# Out:
#                  Close
# Date
# 2017-01-03  527.500000
# 2017-01-04  519.000000
# 2017-01-05  519.500000
# 2017-01-06  514.000000
# 2017-01-09  518.500000
# ...                ...
# 2023-03-27   19.500000
# 2023-03-28   19.629999
# 2023-03-29   18.809999
# 2023-03-30   18.480000
# 2023-03-31   17.709999
#
# [1572 rows x 1 columns]

# %%
fig, ax = plt.subplots(1, 1)#plotting historical close prices
ax.plot(dataSPXS_close, label ='SPXS Close Price')
ax.plot(dataSPXL_close, label ='SPXL Close Price')
ax.plot(dataSPY_close, label ='SPY Close Price')

ax.set_xlabel('Date',fontsize=15)
ax.tick_params(axis='x', rotation=45,)
ax.set_ylabel('Close price',fontsize=15)
ax.legend()
plt.title("Close Prices of the 3 ETFs since 2017")
ax.grid(axis='x', linestyle='--')
ax.grid(axis='y', linestyle='--')
fig.tight_layout() 
plt.show()

# %%
dataSPXS_close_log_ret=np.log(dataSPXS_close).pct_change()#computing the daily log-returns of the close prices
dataSPXS_close_log_ret.rename(columns={dataSPXS_close_log_ret.columns[0]:'SPXS Log-Returns'},inplace=True)
dataSPXS_close_log_ret.dropna(inplace=True)

dataSPXL_close_log_ret=np.log(dataSPXL_close).pct_change()
dataSPXL_close_log_ret.rename(columns={dataSPXL_close_log_ret.columns[0]:'SPXL Log-Returns'},inplace=True)
dataSPXL_close_log_ret.dropna(inplace=True)

dataSPY_close_log_ret=np.log(dataSPY_close).pct_change()
dataSPY_close_log_ret.rename(columns={dataSPY_close_log_ret.columns[0]:'SPY Log-Returns'},inplace=True)
dataSPY_close_log_ret.dropna(inplace=True)

data_log_returns=pd.concat([dataSPXS_close_log_ret,dataSPXL_close_log_ret,dataSPY_close_log_ret],axis=1)
data_log_returns
# Out:
#             SPXS Log-Returns  SPXL Log-Returns  SPY Log-Returns
# Date
# 2017-01-04         -0.002592          0.005300         0.001095
# 2017-01-05          0.000154         -0.000698        -0.000147
# 2017-01-06         -0.001702          0.003368         0.000659
# 2017-01-09          0.001396         -0.002848        -0.000609
# 2017-01-10          0.000462         -0.000268         0.000000
# ...                      ...               ...              ...
# 2023-03-27         -0.001890          0.001219         0.000312
# 2023-03-28          0.002237         -0.001541        -0.000376
# 2023-03-29         -0.014333          0.010188         0.002413
# 2023-03-30         -0.006032          0.003795         0.000974
# 2023-03-31         -0.014592          0.009677         0.002332
#
# [1571 rows x 3 columns]

# %%
fig, ax = plt.subplots(1, 1) #Plotting the returns (not very clear if plotted together)
#ax.plot(dataSPXS_close_log_ret, label ='SPXS Log Returns')
ax.plot(dataSPXL_close_log_ret, label ='SPXL Log Returns')
#ax.plot(dataSPY_close_log_ret, label ='SPY Log Returns')

ax.set_xlabel('Date',fontsize=15)
ax.tick_params(axis='x', rotation=45)
ax.set_ylabel('Log Returns',fontsize=15)
ax.legend()
plt.title("Log Returns of the 3 ETFs since 2017",fontsize=20)
ax.grid(axis='x', linestyle='--')
fig.tight_layout() 
plt.show()

# %% [markdown]
# ##  Some statistics on annualised Log-Returns

# %%
annualised_stats = data_log_returns.resample('Y').agg(['mean','std','skew'])
annualised_stats
# Out:
#            SPXS Log-Returns                     SPXL Log-Returns            \
#                        mean       std      skew             mean       std
# Date
# 2017-12-31        -0.000376  0.002066  0.358143         0.000544  0.003556
# 2018-12-31         0.000035  0.005694  0.232023        -0.000289  0.008659
# 2019-12-31        -0.000622  0.004401  0.531389         0.000742  0.006200
# 2020-12-31        -0.001052  0.012918 -0.002549         0.000259  0.018656
# 2021-12-31        -0.001046  0.007590  0.249828         0.000604  0.005333
# 2022-12-31         0.000525  0.014707 -0.137040        -0.000680  0.010459
# 2023-12-31        -0.001188  0.010641  0.076281         0.000656  0.007418
#
#                      SPY Log-Returns
#                 skew            mean       std      skew
# Date
# 2017-12-31 -0.538835        0.000124  0.000774 -0.437125
# 2018-12-31 -0.484187       -0.000045  0.001938 -0.449432
# 2019-12-31 -0.636612        0.000179  0.001403 -0.614127
# ...

# %%
Sharpe_SPXS= data_log_returns['SPXS Log-Returns'].resample('Y').mean()/data_log_returns['SPXS Log-Returns'].resample('Y').std()*np.sqrt(252)
Sharpe_SPXL= data_log_returns['SPXL Log-Returns'].resample('Y').mean()/data_log_returns['SPXL Log-Returns'].resample('Y').std()*np.sqrt(252)
Sharpe_SPY = data_log_returns['SPY Log-Returns'].resample('Y').mean()/data_log_returns['SPY Log-Returns'].resample('Y').std()*np.sqrt(252)
Sharpe_ratios = pd.DataFrame()
Sharpe_ratios['Sharpe_SPXS']=Sharpe_SPXS
Sharpe_ratios['Sharpe_SPXL']=Sharpe_SPXL
Sharpe_ratios['Sharpe_SPY']=Sharpe_SPY
Sharpe_ratios
# Out:
#             Sharpe_SPXS  Sharpe_SPXL  Sharpe_SPY
# Date
# 2017-12-31    -2.890433     2.430511    2.533861
# 2018-12-31     0.098079    -0.529473   -0.370075
# 2019-12-31    -2.243016     1.899049    2.023072
# 2020-12-31    -1.292682     0.220747    0.455103
# 2021-12-31    -2.187360     1.797775    1.833984
# 2022-12-31     0.566593    -1.032751   -0.867306
# 2023-12-31    -1.771626     1.402888    1.645779

# %%
correlation_matrix=data_log_returns.corr()
correlation_matrix
# Out:
#                   SPXS Log-Returns  SPXL Log-Returns  SPY Log-Returns
# SPXS Log-Returns          1.000000         -0.926278        -0.954458
# SPXL Log-Returns         -0.926278          1.000000         0.992486
# SPY Log-Returns          -0.954458          0.992486         1.000000

# %% [markdown]
# ## Power profiles and Gamma effects

# %%
def period_return(per_ret):
    return np.prod(per_ret + 1)- 1

# %%
rolling_returns=pd.DataFrame()
per_ret_SPXS=dataSPXS_close.pct_change()
rolling_SPXS= per_ret_SPXS.rolling('365D').apply(period_return)
rolling_returns['1 Year Rolling Returns SPXS']=rolling_SPXS.mul(100)

per_ret_SPXL=dataSPXL_close.pct_change()
rolling_SPXL= per_ret_SPXL.rolling('365D').apply(period_return)
rolling_returns['1 Year Rolling Returns SPXL']=rolling_SPXL.mul(100)

per_ret_SPY=dataSPY_close.pct_change()
rolling_SPY= per_ret_SPY.rolling('365D').apply(period_return)
rolling_returns['1 Year Rolling Returns SPY']=rolling_SPY.mul(100)

rolling_returns = rolling_returns.dropna()
rolling_returns
# Out:
#             1 Year Rolling Returns SPXS  1 Year Rolling Returns SPXL  \
# Date
# 2017-01-04                    -1.611374                     1.772248
# 2017-01-05                    -1.516588                     1.535945
# 2017-01-06                    -2.559242                     2.681091
# 2017-01-09                    -1.706161                     1.708629
# 2017-01-10                    -1.421801                     1.617737
# ...                                 ...                          ...
# 2023-03-27                    11.174452                   -44.748401
# 2023-03-28                    14.194287                   -46.271804
# 2023-03-29                    13.655590                   -45.931778
# 2023-03-30                     9.869203                   -44.057669
# 2023-03-31                     0.567848                   -38.914860
#
#             1 Year Rolling Returns SPY
# Date
# 2017-01-04                    0.594920
# 2017-01-05                    0.515001
# ...

# %%
plt.scatter(x=rolling_returns['1 Year Rolling Returns SPY'],y=rolling_returns['1 Year Rolling Returns SPXS'],s=1.)
plt.scatter(x=rolling_returns['1 Year Rolling Returns SPY'],y=rolling_returns['1 Year Rolling Returns SPXL'],s=1.)
plt.title('Historical plot of VT/V0',fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
roll_ret_SPXS=[]
roll_ret_SPXL=[]
roll_ret_SPY=[]
for i in range(1319):
    roll_ret_SPXS.append((dataSPY_close.iloc[i+252,0]/dataSPY_close.iloc[i,0])**-3)
    roll_ret_SPXL.append((dataSPY_close.iloc[i+252,0]/dataSPY_close.iloc[i,0])**3)
    roll_ret_SPY.append(dataSPY.iloc[i+252,0]/dataSPY.iloc[i,0])
    

plt.scatter(x=roll_ret_SPY,y=roll_ret_SPXS,s=1.)    
plt.scatter(x=roll_ret_SPY,y=roll_ret_SPXL,s=1.)

plt.title("Plot of VT/V0 without trading impact",fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Gamma Effect

# %%
def gamma_effect(l):
    return -0.5*(l**2-l)
rolling_returns['accumulated_var']=(data_log_returns['SPY Log-Returns']**2).rolling(252).sum().dropna()
rolling_returns['with_trade_impact_SPXS']=np.exp(gamma_effect(-3)*rolling_returns['accumulated_var'])*rolling_returns['1 Year Rolling Returns SPXS']
rolling_returns['with_trade_impact_SPXL']=np.exp(gamma_effect(3)*rolling_returns['accumulated_var'])*rolling_returns['1 Year Rolling Returns SPXL']

# %%
plt.scatter(x=rolling_returns['1 Year Rolling Returns SPY'],y=rolling_returns['with_trade_impact_SPXS'],s=1.)    
plt.scatter(x=rolling_returns['1 Year Rolling Returns SPY'],y=rolling_returns['with_trade_impact_SPXL'],s=1.)
plt.title('Plot of VT/V0 with trading impact',fontsize=10)
# Out:
# Text(0.5, 1.0, 'Plot of VT/V0 with trading impact')

# %% [markdown]
# ##### Tadaaa !

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### This analysis shows that if an investor is not willing to take the risk to lose money in short periods of time, or if he is not able to actively switch strategy as market mooves, there are probably other products that would suit his investments better. The FAQ of Direxion is quite clear on that matter. However, if layman investors are warned, there are probably not taught about the trading impact of those strategies. If I were them, I would have loved more detailled explanation on how those leverage ETFs work.

# %% [markdown]
# #### I think those products should not be taken out of the advisory list. If investors start doubting about those products, they should be reminded of how those products work and what should be expected

# %%
AZER
